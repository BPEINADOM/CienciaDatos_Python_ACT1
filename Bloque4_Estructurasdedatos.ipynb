# %% [markdown]
# # **Bloque 4: Estructuras de datos**

# %% [markdown]
# ### Ejercicio 10: Crear una lista con 5 frutas e imprimir la tercera

# %%
frutas = ["manzana", "banana", "naranja", "pera", "uva"]

print("La tercera fruta es:", frutas[2])
# Out:
# La tercera fruta es: naranja

# %% [markdown]
# ### Ejercicio 11: Añadir un elemento a la lista anterior

# %%
frutas.append("mango")

print("Lista actualizada:", frutas)
# Out:
# Lista actualizada: ['manzana', 'banana', 'naranja', 'pera', 'uva', 'mango']

# %% [markdown]
# ### Ejercicio 12: Crear una tupla con 3 ciudades y recorrerla con un ciclo

# %%
ciudades = ("Bogotá", "Medellín", "Cali")

for ciudad in ciudades:
    print(ciudad)
# Out:
# Bogotá
# Medellín
# Cali

# %% [markdown]
# ### Ejercicio 13: Crear un diccionario con productos y precios y mostrar las claves

# %%
productos = {
    "arroz": 3000,
    "leche": 2500,
    "pan": 1500
}

print("Claves del diccionario:", productos.keys())
# Out:
# Claves del diccionario: dict_keys(['arroz', 'leche', 'pan'])
